# %%
import requests
from requests.exceptions import HTTPError
 
for url in ['https://yandex.ru/images/search?text=knot&type=photo&icolor=gray&from=tabbar']:
    try:
        response = requests.get(url)
 
        # если ответ успешен, исключения задействованы не будут
        response.raise_for_status()
    except HTTPError as http_err:
        print(f'HTTP error occurred: {http_err}')  # Python 3.6
    except Exception as err:
        print(f'Other error occurred: {err}')  # Python 3.6
    else:
        print('Success!')
# Out:
# Success!

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_15884/1205103360.py in <module>
# ----> 1 response.session
#
# AttributeError: 'Response' object has no attribute 'session'

# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup(response.text, 'html.parser')

print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="i-ua_js_no i-ua_css_standard" lang="ru">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <title>
#    Яндекс Картинки
#   </title>
#   <script nonce="8038991315537780808234">
# ...

# %%
import json
divs = soup.find_all('div', class_='serp-item_type_search')
for item in divs:
    json_data = json.loads(item.get('data-bem'))
    try:
        clean = json_data['serp-item']['preview'][0]['url']
        pica = requests.get(clean, timeout=5)
        except Exception as e:
           
            print('----ERROR---', self.clean)
            return
        if pica.status_code == 200:
            pica = pica.content
            self.clean = self._clear_url(self.clean)
            with open(f'{PATH}{self.search}/{self.clean[-22:]}', 'wb') as p:
                p.write(pica)
            self._print_ok()
    except KeyError:
        continue
    
    print(clean)
    break
#     if self.clean[-3:] in ['jpg', 'png', 'peg', 'gif', 'svg', 'ebp']:
#         self._look_save_pics()
#     #     try:
#                 self.clean = json_data['serp-item']['preview'][0]['origin']['url']
#             except KeyError:
#                 continue
#             if self.clean[-3:] in ['jpg', 'png', 'peg', 'gif', 'svg', 'ebp']:
#                 self._look_save_pics()
#         else:
# Out:
# https://catherineasquithgallery.com/uploads/posts/2021-03/1614572626_88-p-nitki-na-belom-fone-114.png
